# %% [markdown]
# # Grokking on Algorithmic Tasks

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import random
from typing import List, Optional
from pysat.solvers import Glucose4  # or another SAT solver from python-sat

# %%
def generate_random_3sat_instance(
    n_vars: int,
    ratio: float = 4.2,
    seed: Optional[int] = None
):
    """
    Generate a random 3-SAT instance with n_vars variables and k clauses, 
    where k = int(ratio * n_vars). Each clause has exactly 3 literals.
    
    Returns:
        - clauses: a list of lists, each sub-list is [lit1, lit2, lit3],
          where each lit is an integer in {1..n_vars, -1..-n_vars}.
          A positive integer p means variable p is not negated,
          a negative integer -p means variable p is negated.
    """
    if seed is not None:
        random.seed(seed)

    n_clauses = int(ratio * n_vars)
    clauses = []
    for _ in range(n_clauses):
        # Randomly choose 3 distinct variables out of n_vars
        vars_in_clause = random.sample(range(1, n_vars + 1), 3)
        # Randomly negate some of them
        clause = [v if random.random() < 0.5 else -v for v in vars_in_clause]
        clauses.append(clause)
    return clauses


def solve_3sat(clauses: List[List[int]], n_vars: int):
    """
    Solve the given 3-SAT instance (clauses) with n_vars using a SAT solver.
    Returns a list of length n_vars with True/False assignments, or None if unsat.
    """
    solver = Glucose4()
    for clause in clauses:
        solver.add_clause(clause)
    sat = solver.solve()
    if not sat:
        solver.delete()
        return None
    model = solver.get_model()  # list of ints with sign indicating T/F
    solver.delete()

    # model might have length >= n_vars (depending on the solver),
    # but we only care about the first n_vars in absolute value:
    assignment = [False] * n_vars
    for lit in model:
        idx = abs(lit) - 1
        if 0 <= idx < n_vars:
            assignment[idx] = (lit > 0)
    return assignment


class ThreeSatDataset(Dataset):
    """
    Creates a dataset of random 3-SAT instances along with a known satisfying assignment.
    Each item is:
        input_representation, assignment
    Where:
        - input_representation: a token-like encoding of the 3-SAT instance
        - assignment: a list of length n_vars in {0,1}, representing F or T.
    """

    def __init__(
        self,
        num_samples: int,
        n_vars: int,
        ratio: float = 4.2,
        max_tries: int = 1000,
        skip_unsat: bool = True
    ):
        super().__init__()
        self.data = []
        self.n_vars = n_vars

        count = 0
        while len(self.data) < num_samples and count < max_tries:
            clauses = generate_random_3sat_instance(n_vars, ratio)
            solution = solve_3sat(clauses, n_vars)
            if solution is not None:
                # We have a satisfiable instance
                input_repr = self._encode_instance(clauses, n_vars)
                assignment = [1 if x else 0 for x in solution]
                self.data.append((input_repr, assignment))
            else:
                if not skip_unsat:
                    # We'll store unsat instance with a placeholder assignment
                    input_repr = self._encode_instance(clauses, n_vars)
                    assignment = [0] * n_vars  # or any fallback
                    self.data.append((input_repr, assignment))
            count += 1

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

    def _encode_instance(self, clauses: List[List[int]], n_vars: int):
        """
        Encode the 3-SAT instance as a list of integer tokens (or any token representation).
        Example simplistic encoding scheme:
            - We'll start with a special token for "start of instance", e.g. 0
            - For each clause, we add tokens [ var1, var2, var3, <sep> ]
              where var is +x or -x mapped to distinct integer IDs.
            - End with a <end> token.
        The mapping is arbitrary as long as it's consistent.
        
        Return a list of ints that the Transformer can embed.
        """
        tokens = [0]  # start token
        # We'll map literal i (±1..±n_vars) to int: +x -> x, -x -> n_vars + |x|
        # That is, pos i in [1..n_vars] = i, neg i = n_vars + |i|.
        for clause in clauses:
            for lit in clause:
                if lit > 0:
                    tokens.append(lit)  # e.g. 1..n_vars
                else:
                    tokens.append(n_vars + abs(lit))  # e.g. n_vars+1..2*n_vars
            tokens.append(2 * n_vars + 1)  # a <sep> token
        tokens.append(2 * n_vars + 2)  # <end> token
        return torch.tensor(tokens, dtype=torch.long)

# %%
class TransformerBlock(nn.Module):
    """
    A single Transformer block with multi-head attention and a GELU feedforward.
    """
    def __init__(self, d_model, n_heads, d_ff):
        super().__init__()
        self.attn = nn.MultiheadAttention(embed_dim=d_model, num_heads=n_heads, batch_first=True)
        self.attn_ln = nn.RMSNorm(d_model)

        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.GELU(),
            nn.Linear(d_ff, d_model)
        )
        self.ff_ln = nn.RMSNorm(d_model)

    def forward(self, x, mask=None):
        # x shape: (batch, seq_len, d_model)
        attn_out, _ = self.attn(x, x, x, attn_mask=mask)
        x = self.attn_ln(x + attn_out)
        ff_out = self.ff(x)
        x = self.ff_ln(x + ff_out)
        return x


class TransformerModel(nn.Module):
    """
    Minimal Transformer-based model:
      - An embedding layer
      - N Transformer blocks
      - A readout that produces a sequence of length n_vars (the T/F assignment)
    """
    def __init__(
        self,
        vocab_size,
        d_model=128,
        n_heads=4,
        d_ff=512,
        num_layers=4,
        n_vars=10
    ):
        super().__init__()
        self.n_vars = n_vars
        self.d_model = d_model
        self.embed = nn.Embedding(vocab_size, d_model)

        self.blocks = nn.ModuleList([
            TransformerBlock(d_model, n_heads, d_ff)
            for _ in range(num_layers)
        ])
        self.final_ln = nn.RMSNorm(d_model)

        # We will produce an output for each variable in {0,1}:
        # i.e. a classification "head" that returns a T/F assignment per variable.
        # We'll do this by reading the final hidden state from the [start] token 
        # (or something else) and projecting into n_vars*2, or produce an entire sequence.
        #
        # For simplicity, let's produce a single vector (batch, d_model) from the
        # [start] token, and then map that to (batch, n_vars, 2).
        self.classifier = nn.Linear(d_model, n_vars * 2)

    def forward(self, x, mask=None):
        """
        x: (batch, seq_len)
        Return shape: (batch, n_vars, 2)
        """
        emb = self.embed(x)  # (batch, seq_len, d_model)
        hidden = emb
        for block in self.blocks:
            hidden = block(hidden, mask=mask)
        hidden = self.final_ln(hidden)

        # Let's index the first token [start] = hidden[:,0,:]
        start_token_hidden = hidden[:, 0, :]  # (batch, d_model)
        logits = self.classifier(start_token_hidden)  # (batch, n_vars*2)
        logits = logits.view(-1, self.n_vars, 2)      # (batch, n_vars, 2)
        return logits

# %%
def collate_fn(batch):
    """
    Collate function for DataLoader.
    We have variable-length input sequences, so we'll pad them.
    """
    inputs = [b[0] for b in batch]
    targets = [b[1] for b in batch]

    # Pad inputs
    input_lens = [len(i) for i in inputs]
    max_len = max(input_lens)
    padded_inputs = []
    for inp in inputs:
        pad_len = max_len - len(inp)
        padded_inp = torch.cat([inp, torch.zeros(pad_len, dtype=torch.long)], dim=0)
        padded_inputs.append(padded_inp)
    padded_inputs = torch.stack(padded_inputs, dim=0)

    # Targets are all length n_vars
    targets = torch.tensor(targets, dtype=torch.long)

    return padded_inputs, targets


def main():
    # Hyperparameters
    N_VARS = 5      # number of variables per sample
    RATIO = 3.0      # clauses-to-variables ratio
    TRAIN_SAMPLES = 200000
    VAL_SAMPLES = 20000
    BATCH_SIZE = 128
    EPOCHS = 1000
    LR = 1e-3

    # We define the vocabulary size:
    #   - For each variable index i in 1..n_vars, we have a token i for the positive literal
    #   - For each negative literal, we have n_vars + i
    #   - We add 1 special <sep> token, 1 <end> token, and 1 <start> token
    # So in total: 2*n_vars + 2 or 2*n_vars + a handful of special tokens
    # We'll define them as:
    vocab_size = 2*N_VARS + 3  # 3 for [start], <sep>, <end> (some margin)

    # Create dataset
    train_ds = ThreeSatDataset(num_samples=TRAIN_SAMPLES, n_vars=N_VARS, ratio=RATIO)
    val_ds = ThreeSatDataset(num_samples=VAL_SAMPLES, n_vars=N_VARS, ratio=RATIO)

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn)

    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    print("Using device:", device)

    # Create model
    model = TransformerModel(
        vocab_size=vocab_size,
        d_model=512,
        n_heads=8,
        d_ff=2048,
        num_layers=8,
        n_vars=N_VARS
    ).to(device)

    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(model.parameters(), lr=LR)

    train_losses = []
    val_losses = []

    # Training loop
    for epoch in range(EPOCHS):
        model.train()
        total_loss = 0.0
        
        for batch_inp, batch_tgt in train_loader:
            batch_inp = batch_inp.to(device)
            batch_tgt = batch_tgt.to(device)  # shape: (batch, n_vars)

            optimizer.zero_grad()
            logits = model(batch_inp)        # (batch, n_vars, 2)
            # Reshape for cross-entropy:
            # We have (batch, n_vars, 2) and want (batch*n_vars, 2) vs (batch*n_vars)
            logits_flat = logits.view(-1, 2)
            targets_flat = batch_tgt.view(-1)
            loss = criterion(logits_flat, targets_flat)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        # Validation
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for batch_inp, batch_tgt in val_loader:
                batch_inp = batch_inp.to(device)
                batch_tgt = batch_tgt.to(device)

                logits = model(batch_inp)
                logits_flat = logits.view(-1, 2)
                targets_flat = batch_tgt.view(-1)
                loss = criterion(logits_flat, targets_flat)
                val_loss += loss.item()
        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        print(f"Epoch {epoch+1}/{EPOCHS} | Train Loss: {avg_loss:.4f} | Val Loss: {val_loss:.4f}")

        if (epoch + 1) % 10 == 0:
            model.eval()
            test_clauses = generate_random_3sat_instance(N_VARS, RATIO)
            test_solution = solve_3sat(test_clauses, N_VARS)
            encoded = train_ds._encode_instance(test_clauses, N_VARS).unsqueeze(0).to(device)
            with torch.no_grad():
                pred_logits = model(encoded)
                pred = pred_logits.argmax(dim=-1).squeeze(0).cpu().tolist()
            
            print("\nSample test case:")
            print("Clauses:", test_clauses)
            print("SAT solver solution:", [1 if x else 0 for x in test_solution])
            print("Model prediction:", pred)
            print("Match:", pred == [1 if x else 0 for x in test_solution], "\n")

if __name__ == "__main__":
    main()
# Out:
# Using device: mps
# Epoch 1/1000 | Train Loss: 1.4204 | Val Loss: 0.7608
# Percentage of all-zero predictions: 0.00%
# Epoch 2/1000 | Train Loss: 0.6980 | Val Loss: 0.6524
# Percentage of all-zero predictions: 0.00%
# Epoch 3/1000 | Train Loss: 0.6404 | Val Loss: 0.6207
# Percentage of all-zero predictions: 0.00%
# Epoch 4/1000 | Train Loss: 0.6349 | Val Loss: 0.6192
# Percentage of all-zero predictions: 100.00%
# Epoch 5/1000 | Train Loss: 0.6338 | Val Loss: 0.6199
# Percentage of all-zero predictions: 0.00%
# Epoch 6/1000 | Train Loss: 0.6319 | Val Loss: 0.6191
# Percentage of all-zero predictions: 100.00%
# Epoch 7/1000 | Train Loss: 0.6379 | Val Loss: 0.6202
# Percentage of all-zero predictions: 0.00%
# Epoch 8/1000 | Train Loss: 0.6326 | Val Loss: 0.6182
# Percentage of all-zero predictions: 0.00%
# Epoch 9/1000 | Train Loss: 0.6283 | Val Loss: 0.6209
# Percentage of all-zero predictions: 0.00%
# Epoch 10/1000 | Train Loss: 0.6287 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-5, -3, 2], [1, -5, -2], [-1, 3, -4], [3, -5, 1], [-2, 1, 4], [-3, -1, -2], [1, 4, 3], [3, 2, -5], [-3, -4, 1], [-4, 2, -5], [3, 2, -4], [4, -1, 5], [4, 2, 3], [5, -2, 1], [5, -3, -2]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 11/1000 | Train Loss: 0.6290 | Val Loss: 0.6192
# Percentage of all-zero predictions: 100.00%
# Epoch 12/1000 | Train Loss: 0.6300 | Val Loss: 0.6322
# Percentage of all-zero predictions: 0.00%
# Epoch 13/1000 | Train Loss: 0.6356 | Val Loss: 0.6169
# Percentage of all-zero predictions: 100.00%
# Epoch 14/1000 | Train Loss: 0.6303 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 15/1000 | Train Loss: 0.6333 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 16/1000 | Train Loss: 0.6351 | Val Loss: 0.6247
# Percentage of all-zero predictions: 0.00%
# Epoch 17/1000 | Train Loss: 0.6324 | Val Loss: 0.6313
# Percentage of all-zero predictions: 0.00%
# Epoch 18/1000 | Train Loss: 0.6408 | Val Loss: 0.6173
# Percentage of all-zero predictions: 100.00%
# Epoch 19/1000 | Train Loss: 0.6334 | Val Loss: 0.6205
# Percentage of all-zero predictions: 0.00%
# Epoch 20/1000 | Train Loss: 0.6260 | Val Loss: 0.6247
# Percentage of all-zero predictions: 0.00%
#
# Sample test case:
# Clauses: [[-5, -4, -2], [4, -3, 1], [5, 2, 1], [1, -3, 2], [5, 1, -3], [-3, 2, 4], [-5, 2, -1], [1, 4, 2], [2, -3, 4], [-1, 2, 4], [5, -3, -1], [-1, -5, 3], [2, 1, 4], [3, -5, 2], [3, -5, -1]]
# SAT solver solution: [1, 1, 0, 0, 0]
# Model prediction: [1, 0, 0, 0, 0]
# Match: False
#
# Epoch 21/1000 | Train Loss: 0.6318 | Val Loss: 0.6223
# Percentage of all-zero predictions: 0.00%
# Epoch 22/1000 | Train Loss: 0.6335 | Val Loss: 0.6161
# Percentage of all-zero predictions: 100.00%
# Epoch 23/1000 | Train Loss: 0.6307 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 24/1000 | Train Loss: 0.6284 | Val Loss: 0.6205
# Percentage of all-zero predictions: 0.00%
# Epoch 25/1000 | Train Loss: 0.6290 | Val Loss: 0.6197
# Percentage of all-zero predictions: 100.00%
# Epoch 26/1000 | Train Loss: 0.6299 | Val Loss: 0.6228
# Percentage of all-zero predictions: 0.00%
# Epoch 27/1000 | Train Loss: 0.6318 | Val Loss: 0.6184
# Percentage of all-zero predictions: 100.00%
# Epoch 28/1000 | Train Loss: 0.6301 | Val Loss: 0.6210
# Percentage of all-zero predictions: 100.00%
# Epoch 29/1000 | Train Loss: 0.6318 | Val Loss: 0.6253
# Percentage of all-zero predictions: 0.00%
# Epoch 30/1000 | Train Loss: 0.6337 | Val Loss: 0.6310
# Percentage of all-zero predictions: 0.00%
#
# Sample test case:
# Clauses: [[4, -1, 2], [3, 2, -1], [3, -5, -4], [-2, -1, 4], [-1, -4, 5], [-2, 1, 5], [-1, 3, 5], [-5, 3, -1], [-4, 2, 5], [-5, -2, -4], [-3, 5, 2], [3, -1, 4], [-2, 5, 3], [-4, -1, -2], [4, 3, -5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 1, 1, 0, 0]
# Match: False
#
# Epoch 31/1000 | Train Loss: 0.6332 | Val Loss: 0.6174
# Percentage of all-zero predictions: 100.00%
# Epoch 32/1000 | Train Loss: 0.6271 | Val Loss: 0.6208
# Percentage of all-zero predictions: 0.00%
# Epoch 33/1000 | Train Loss: 0.6278 | Val Loss: 0.6189
# Percentage of all-zero predictions: 100.00%
# Epoch 34/1000 | Train Loss: 0.6287 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 35/1000 | Train Loss: 0.6296 | Val Loss: 0.6174
# Percentage of all-zero predictions: 0.00%
# Epoch 36/1000 | Train Loss: 0.6310 | Val Loss: 0.6210
# Percentage of all-zero predictions: 0.00%
# Epoch 37/1000 | Train Loss: 0.6308 | Val Loss: 0.6189
# Percentage of all-zero predictions: 100.00%
# Epoch 38/1000 | Train Loss: 0.6320 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 39/1000 | Train Loss: 0.6309 | Val Loss: 0.6281
# Percentage of all-zero predictions: 0.00%
# Epoch 40/1000 | Train Loss: 0.6284 | Val Loss: 0.6168
# Percentage of all-zero predictions: 0.00%
#
# Sample test case:
# Clauses: [[5, -4, 1], [5, 2, 4], [-4, 3, 1], [-1, 4, 2], [5, -1, -3], [3, -4, 2], [-2, -5, 3], [2, 4, -1], [-4, 5, -2], [2, -3, -4], [2, 4, 3], [2, 5, -1], [5, -3, -4], [3, 2, 5], [1, -5, -2]]
# SAT solver solution: [0, 1, 0, 0, 0]
# Model prediction: [1, 0, 0, 0, 0]
# Match: False
#
# Epoch 41/1000 | Train Loss: 0.6302 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 42/1000 | Train Loss: 0.6274 | Val Loss: 0.6167
# Percentage of all-zero predictions: 0.00%
# Epoch 43/1000 | Train Loss: 0.6302 | Val Loss: 0.6303
# Percentage of all-zero predictions: 100.00%
# Epoch 44/1000 | Train Loss: 0.6278 | Val Loss: 0.6164
# Percentage of all-zero predictions: 0.00%
# Epoch 45/1000 | Train Loss: 0.6297 | Val Loss: 0.6182
# Percentage of all-zero predictions: 100.00%
# Epoch 46/1000 | Train Loss: 0.6291 | Val Loss: 0.6235
# Percentage of all-zero predictions: 0.00%
# Epoch 47/1000 | Train Loss: 0.6293 | Val Loss: 0.6181
# Percentage of all-zero predictions: 100.00%
# Epoch 48/1000 | Train Loss: 0.6266 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
# Epoch 49/1000 | Train Loss: 0.6275 | Val Loss: 0.6226
# Percentage of all-zero predictions: 0.00%
# Epoch 50/1000 | Train Loss: 0.6289 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, 2, 3], [-4, 1, 5], [-3, 4, -2], [-3, -4, 1], [-3, -5, -2], [1, 4, -3], [-5, 4, -3], [3, 5, -2], [-2, -3, -5], [-4, -5, 1], [3, -5, 4], [-1, -2, -5], [-5, -4, -3], [1, 5, -2], [4, -1, -5]]
# SAT solver solution: [1, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 51/1000 | Train Loss: 0.6310 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 52/1000 | Train Loss: 0.6300 | Val Loss: 0.6193
# Percentage of all-zero predictions: 100.00%
# Epoch 53/1000 | Train Loss: 0.6289 | Val Loss: 0.6212
# Percentage of all-zero predictions: 0.00%
# Epoch 54/1000 | Train Loss: 0.6321 | Val Loss: 0.6159
# Percentage of all-zero predictions: 0.00%
# Epoch 55/1000 | Train Loss: 0.6302 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 56/1000 | Train Loss: 0.6296 | Val Loss: 0.6182
# Percentage of all-zero predictions: 0.00%
# Epoch 57/1000 | Train Loss: 0.6292 | Val Loss: 0.6175
# Percentage of all-zero predictions: 100.00%
# Epoch 58/1000 | Train Loss: 0.6293 | Val Loss: 0.6199
# Percentage of all-zero predictions: 100.00%
# Epoch 59/1000 | Train Loss: 0.6306 | Val Loss: 0.6210
# Percentage of all-zero predictions: 0.00%
# Epoch 60/1000 | Train Loss: 0.6301 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, 1, -2], [-1, 2, 5], [5, 4, -1], [-4, 1, -2], [-2, -1, 3], [-4, -3, -5], [3, -5, -1], [2, 4, -1], [1, -2, 3], [-4, 1, -5], [3, -2, -4], [-3, 1, -4], [4, 1, 5], [-1, -2, -3], [4, -3, -5]]
# SAT solver solution: [0, 0, 0, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 61/1000 | Train Loss: 0.6294 | Val Loss: 0.6134
# Percentage of all-zero predictions: 100.00%
# Epoch 62/1000 | Train Loss: 0.6271 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 63/1000 | Train Loss: 0.6304 | Val Loss: 0.6220
# Percentage of all-zero predictions: 0.00%
# Epoch 64/1000 | Train Loss: 0.6315 | Val Loss: 0.6223
# Percentage of all-zero predictions: 0.00%
# Epoch 65/1000 | Train Loss: 0.6308 | Val Loss: 0.6214
# Percentage of all-zero predictions: 0.00%
# Epoch 66/1000 | Train Loss: 0.6317 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 67/1000 | Train Loss: 0.6308 | Val Loss: 0.6227
# Percentage of all-zero predictions: 0.00%
# Epoch 68/1000 | Train Loss: 0.6288 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 69/1000 | Train Loss: 0.6278 | Val Loss: 0.6170
# Percentage of all-zero predictions: 100.00%
# Epoch 70/1000 | Train Loss: 0.6311 | Val Loss: 0.6245
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-1, 5, 3], [2, -1, 3], [4, -3, -2], [5, 4, 2], [1, -2, 3], [-2, -3, -5], [-4, -1, 2], [-5, -4, 2], [5, -3, 1], [-1, 4, -5], [3, 4, -5], [-4, 5, 3], [-2, 3, -1], [-2, -4, 3], [-1, 4, -3]]
# SAT solver solution: [1, 1, 1, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 71/1000 | Train Loss: 0.6319 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 72/1000 | Train Loss: 0.6265 | Val Loss: 0.6159
# Percentage of all-zero predictions: 100.00%
# Epoch 73/1000 | Train Loss: 0.6287 | Val Loss: 0.6199
# Percentage of all-zero predictions: 0.00%
# Epoch 74/1000 | Train Loss: 0.6315 | Val Loss: 0.6201
# Percentage of all-zero predictions: 0.00%
# Epoch 75/1000 | Train Loss: 0.6315 | Val Loss: 0.6156
# Percentage of all-zero predictions: 100.00%
# Epoch 76/1000 | Train Loss: 0.6269 | Val Loss: 0.6192
# Percentage of all-zero predictions: 0.00%
# Epoch 77/1000 | Train Loss: 0.6282 | Val Loss: 0.6163
# Percentage of all-zero predictions: 0.00%
# Epoch 78/1000 | Train Loss: 0.6260 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
# Epoch 79/1000 | Train Loss: 0.6284 | Val Loss: 0.6186
# Percentage of all-zero predictions: 0.00%
# Epoch 80/1000 | Train Loss: 0.6318 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-3, 2, -1], [-2, -5, -4], [2, -1, 5], [2, -4, -1], [2, -1, -4], [-1, -4, -3], [-1, -4, 2], [5, -4, 1], [-4, -1, 2], [5, -2, -4], [-4, -2, 1], [-2, -1, -5], [-3, -4, 1], [1, -2, 5], [2, -3, 5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 81/1000 | Train Loss: 0.6288 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 82/1000 | Train Loss: 0.6289 | Val Loss: 0.6169
# Percentage of all-zero predictions: 0.00%
# Epoch 83/1000 | Train Loss: 0.6289 | Val Loss: 0.6220
# Percentage of all-zero predictions: 0.00%
# Epoch 84/1000 | Train Loss: 0.6279 | Val Loss: 0.6125
# Percentage of all-zero predictions: 100.00%
# Epoch 85/1000 | Train Loss: 0.6283 | Val Loss: 0.6162
# Percentage of all-zero predictions: 100.00%
# Epoch 86/1000 | Train Loss: 0.6269 | Val Loss: 0.6162
# Percentage of all-zero predictions: 100.00%
# Epoch 87/1000 | Train Loss: 0.6306 | Val Loss: 0.6221
# Percentage of all-zero predictions: 100.00%
# Epoch 88/1000 | Train Loss: 0.6340 | Val Loss: 0.6161
# Percentage of all-zero predictions: 100.00%
# Epoch 89/1000 | Train Loss: 0.6333 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 90/1000 | Train Loss: 0.6339 | Val Loss: 0.6265
# Percentage of all-zero predictions: 0.00%
#
# Sample test case:
# Clauses: [[-4, 5, 1], [-1, -2, 4], [-4, -2, -5], [-2, -3, -1], [2, 1, -4], [3, -4, 1], [-2, -5, 3], [3, -4, -5], [-5, -3, 4], [-3, 2, -5], [5, -3, -2], [5, 4, 1], [3, -1, -5], [-5, 1, -4], [2, -4, -5]]
# SAT solver solution: [1, 0, 0, 0, 0]
# Model prediction: [0, 1, 0, 0, 0]
# Match: False
#
# Epoch 91/1000 | Train Loss: 0.6316 | Val Loss: 0.6216
# Percentage of all-zero predictions: 0.00%
# Epoch 92/1000 | Train Loss: 0.6298 | Val Loss: 0.6157
# Percentage of all-zero predictions: 0.00%
# Epoch 93/1000 | Train Loss: 0.6288 | Val Loss: 0.6162
# Percentage of all-zero predictions: 100.00%
# Epoch 94/1000 | Train Loss: 0.6269 | Val Loss: 0.6164
# Percentage of all-zero predictions: 0.00%
# Epoch 95/1000 | Train Loss: 0.6285 | Val Loss: 0.6195
# Percentage of all-zero predictions: 0.00%
# Epoch 96/1000 | Train Loss: 0.6303 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 97/1000 | Train Loss: 0.6272 | Val Loss: 0.6215
# Percentage of all-zero predictions: 0.00%
# Epoch 98/1000 | Train Loss: 0.6290 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 99/1000 | Train Loss: 0.6294 | Val Loss: 0.6256
# Percentage of all-zero predictions: 0.00%
# Epoch 100/1000 | Train Loss: 0.6297 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-1, -2, 5], [-5, -4, -3], [-3, -5, 1], [2, -4, -3], [3, -1, 4], [3, 4, -5], [1, 5, 3], [3, 5, 4], [3, 4, -2], [1, -2, 5], [-4, -2, -3], [-2, -4, -1], [3, 4, -5], [-3, -2, 4], [4, 5, -1]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 101/1000 | Train Loss: 0.6280 | Val Loss: 0.6172
# Percentage of all-zero predictions: 100.00%
# Epoch 102/1000 | Train Loss: 0.6287 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 103/1000 | Train Loss: 0.6270 | Val Loss: 0.6192
# Percentage of all-zero predictions: 0.00%
# Epoch 104/1000 | Train Loss: 0.6284 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 105/1000 | Train Loss: 0.6297 | Val Loss: 0.6181
# Percentage of all-zero predictions: 0.00%
# Epoch 106/1000 | Train Loss: 0.6275 | Val Loss: 0.6129
# Percentage of all-zero predictions: 100.00%
# Epoch 107/1000 | Train Loss: 0.6268 | Val Loss: 0.6161
# Percentage of all-zero predictions: 0.00%
# Epoch 108/1000 | Train Loss: 0.6286 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 109/1000 | Train Loss: 0.6285 | Val Loss: 0.6176
# Percentage of all-zero predictions: 0.00%
# Epoch 110/1000 | Train Loss: 0.6290 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-1, 5, 3], [1, 5, -3], [2, 4, -3], [-1, 2, -4], [-3, 5, 1], [-1, 5, -3], [-5, -1, 3], [5, 3, -2], [-3, 2, 1], [-3, -4, -5], [5, -2, -1], [3, -2, -4], [-3, 2, 4], [-2, 1, -4], [-4, 5, 1]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 111/1000 | Train Loss: 0.6275 | Val Loss: 0.6179
# Percentage of all-zero predictions: 0.00%
# Epoch 112/1000 | Train Loss: 0.6285 | Val Loss: 0.6180
# Percentage of all-zero predictions: 100.00%
# Epoch 113/1000 | Train Loss: 0.6309 | Val Loss: 0.6167
# Percentage of all-zero predictions: 0.00%
# Epoch 114/1000 | Train Loss: 0.6270 | Val Loss: 0.6190
# Percentage of all-zero predictions: 0.00%
# Epoch 115/1000 | Train Loss: 0.6273 | Val Loss: 0.6176
# Percentage of all-zero predictions: 0.00%
# Epoch 116/1000 | Train Loss: 0.6264 | Val Loss: 0.6165
# Percentage of all-zero predictions: 100.00%
# Epoch 117/1000 | Train Loss: 0.6285 | Val Loss: 0.6150
# Percentage of all-zero predictions: 0.00%
# Epoch 118/1000 | Train Loss: 0.6277 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
# Epoch 119/1000 | Train Loss: 0.6295 | Val Loss: 0.6199
# Percentage of all-zero predictions: 100.00%
# Epoch 120/1000 | Train Loss: 0.6280 | Val Loss: 0.6130
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[3, -1, -4], [2, -4, 1], [-2, 3, 4], [2, 3, 5], [3, 2, -5], [-5, 2, 1], [1, 4, -3], [5, -4, -2], [1, 5, 4], [-5, -2, 1], [-5, 1, -3], [2, -1, -3], [-1, -5, 4], [-5, -1, 3], [-4, 1, 2]]
# SAT solver solution: [1, 1, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 121/1000 | Train Loss: 0.6292 | Val Loss: 0.6181
# Percentage of all-zero predictions: 100.00%
# Epoch 122/1000 | Train Loss: 0.6302 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 123/1000 | Train Loss: 0.6280 | Val Loss: 0.6183
# Percentage of all-zero predictions: 100.00%
# Epoch 124/1000 | Train Loss: 0.6273 | Val Loss: 0.6146
# Percentage of all-zero predictions: 0.00%
# Epoch 125/1000 | Train Loss: 0.6277 | Val Loss: 0.6166
# Percentage of all-zero predictions: 100.00%
# Epoch 126/1000 | Train Loss: 0.6263 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 127/1000 | Train Loss: 0.6280 | Val Loss: 0.6165
# Percentage of all-zero predictions: 100.00%
# Epoch 128/1000 | Train Loss: 0.6261 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 129/1000 | Train Loss: 0.6270 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 130/1000 | Train Loss: 0.6261 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, -2, -5], [-5, 3, -1], [-5, -4, -1], [-2, 5, -3], [-4, 2, 1], [3, -1, 5], [-5, 2, -4], [-1, 2, -5], [-4, -2, -1], [2, -4, -3], [-2, -4, 5], [-2, 5, -1], [-1, -5, 3], [-1, 5, -2], [1, -4, -5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 131/1000 | Train Loss: 0.6267 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 132/1000 | Train Loss: 0.6264 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 133/1000 | Train Loss: 0.6274 | Val Loss: 0.6153
# Percentage of all-zero predictions: 0.00%
# Epoch 134/1000 | Train Loss: 0.6275 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
# Epoch 135/1000 | Train Loss: 0.6282 | Val Loss: 0.6157
# Percentage of all-zero predictions: 0.00%
# Epoch 136/1000 | Train Loss: 0.6260 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 137/1000 | Train Loss: 0.6267 | Val Loss: 0.6133
# Percentage of all-zero predictions: 100.00%
# Epoch 138/1000 | Train Loss: 0.6267 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 139/1000 | Train Loss: 0.6286 | Val Loss: 0.6134
# Percentage of all-zero predictions: 100.00%
# Epoch 140/1000 | Train Loss: 0.6269 | Val Loss: 0.6177
# Percentage of all-zero predictions: 0.00%
#
# Sample test case:
# Clauses: [[5, -3, 4], [-5, -1, 4], [5, -1, -3], [2, -1, -5], [-1, -5, 2], [-1, 2, 3], [-4, 5, -3], [-3, -5, 4], [-1, 2, 4], [4, -3, 1], [5, 2, -3], [4, 3, -1], [4, 3, 1], [-3, -5, -1], [-5, 4, 3]]
# SAT solver solution: [0, 0, 0, 1, 0]
# Model prediction: [1, 0, 0, 0, 0]
# Match: False
#
# Epoch 141/1000 | Train Loss: 0.6278 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 142/1000 | Train Loss: 0.6266 | Val Loss: 0.6159
# Percentage of all-zero predictions: 0.00%
# Epoch 143/1000 | Train Loss: 0.6271 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 144/1000 | Train Loss: 0.6271 | Val Loss: 0.6160
# Percentage of all-zero predictions: 100.00%
# Epoch 145/1000 | Train Loss: 0.6254 | Val Loss: 0.6134
# Percentage of all-zero predictions: 100.00%
# Epoch 146/1000 | Train Loss: 0.6261 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 147/1000 | Train Loss: 0.6278 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 148/1000 | Train Loss: 0.6268 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 149/1000 | Train Loss: 0.6274 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 150/1000 | Train Loss: 0.6272 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, -1, 3], [5, 3, 1], [-2, 4, 5], [5, -2, 1], [-1, -4, 5], [1, 2, -5], [-3, -1, 4], [3, 5, -2], [5, -2, 3], [3, 1, 4], [2, -4, 1], [3, -2, -5], [-4, -5, -2], [-5, 2, -1], [5, 4, -1]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 151/1000 | Train Loss: 0.6261 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 152/1000 | Train Loss: 0.6259 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
# Epoch 153/1000 | Train Loss: 0.6260 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 154/1000 | Train Loss: 0.6264 | Val Loss: 0.6150
# Percentage of all-zero predictions: 0.00%
# Epoch 155/1000 | Train Loss: 0.6260 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 156/1000 | Train Loss: 0.6274 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 157/1000 | Train Loss: 0.6264 | Val Loss: 0.6155
# Percentage of all-zero predictions: 100.00%
# Epoch 158/1000 | Train Loss: 0.6256 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 159/1000 | Train Loss: 0.6274 | Val Loss: 0.6147
# Percentage of all-zero predictions: 0.00%
# Epoch 160/1000 | Train Loss: 0.6260 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-2, 4, -5], [-4, 5, 2], [-4, -1, 3], [2, -5, 1], [-4, 5, -1], [-4, 1, 2], [3, 5, 4], [-1, 4, -5], [-1, -5, -4], [1, -4, 3], [1, 5, 4], [1, -2, -3], [-5, 3, 2], [-4, -3, 2], [-2, -4, -5]]
# SAT solver solution: [1, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 161/1000 | Train Loss: 0.6256 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 162/1000 | Train Loss: 0.6277 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 163/1000 | Train Loss: 0.6269 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 164/1000 | Train Loss: 0.6269 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 165/1000 | Train Loss: 0.6264 | Val Loss: 0.6163
# Percentage of all-zero predictions: 0.00%
# Epoch 166/1000 | Train Loss: 0.6271 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 167/1000 | Train Loss: 0.6267 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
# Epoch 168/1000 | Train Loss: 0.6275 | Val Loss: 0.6132
# Percentage of all-zero predictions: 100.00%
# Epoch 169/1000 | Train Loss: 0.6274 | Val Loss: 0.6157
# Percentage of all-zero predictions: 100.00%
# Epoch 170/1000 | Train Loss: 0.6259 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, -1, 2], [2, 4, 3], [-2, -4, -1], [-2, 1, 3], [3, 2, -4], [-1, -2, 5], [3, -4, 1], [-1, 3, 2], [2, 3, 4], [-5, 2, -3], [-5, 1, -3], [-4, 3, -1], [3, -2, -5], [4, -2, 3], [-3, -2, 4]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 171/1000 | Train Loss: 0.6261 | Val Loss: 0.6156
# Percentage of all-zero predictions: 100.00%
# Epoch 172/1000 | Train Loss: 0.6265 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 173/1000 | Train Loss: 0.6254 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 174/1000 | Train Loss: 0.6252 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 175/1000 | Train Loss: 0.6266 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 176/1000 | Train Loss: 0.6260 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 177/1000 | Train Loss: 0.6256 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 178/1000 | Train Loss: 0.6265 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 179/1000 | Train Loss: 0.6261 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
# Epoch 180/1000 | Train Loss: 0.6260 | Val Loss: 0.6133
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[1, -5, 4], [-5, 3, 2], [-4, 3, 2], [-4, 1, 3], [1, 2, -4], [5, 2, -3], [-1, 3, -2], [-4, -3, 5], [-2, 4, -5], [2, 5, -4], [1, -2, 4], [5, 3, 1], [4, 3, -5], [3, 4, -1], [-4, -1, 5]]
# SAT solver solution: [1, 1, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 181/1000 | Train Loss: 0.6259 | Val Loss: 0.6164
# Percentage of all-zero predictions: 100.00%
# Epoch 182/1000 | Train Loss: 0.6274 | Val Loss: 0.6132
# Percentage of all-zero predictions: 100.00%
# Epoch 183/1000 | Train Loss: 0.6261 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
# Epoch 184/1000 | Train Loss: 0.6271 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 185/1000 | Train Loss: 0.6249 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 186/1000 | Train Loss: 0.6255 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 187/1000 | Train Loss: 0.6260 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 188/1000 | Train Loss: 0.6275 | Val Loss: 0.6131
# Percentage of all-zero predictions: 100.00%
# Epoch 189/1000 | Train Loss: 0.6270 | Val Loss: 0.6167
# Percentage of all-zero predictions: 100.00%
# Epoch 190/1000 | Train Loss: 0.6257 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, 2, -1], [1, -3, 5], [-5, -4, -1], [4, 1, -2], [-3, 5, -2], [4, 3, -5], [-2, -4, -5], [1, 5, -2], [-3, -4, 5], [-4, -2, 3], [5, -3, -4], [1, -4, -2], [1, -3, -5], [-2, -5, -3], [2, 3, 1]]
# SAT solver solution: [1, 1, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 191/1000 | Train Loss: 0.6256 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 192/1000 | Train Loss: 0.6256 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 193/1000 | Train Loss: 0.6252 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 194/1000 | Train Loss: 0.6258 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 195/1000 | Train Loss: 0.6278 | Val Loss: 0.6133
# Percentage of all-zero predictions: 100.00%
# Epoch 196/1000 | Train Loss: 0.6265 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 197/1000 | Train Loss: 0.6267 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
# Epoch 198/1000 | Train Loss: 0.6265 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 199/1000 | Train Loss: 0.6259 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 200/1000 | Train Loss: 0.6254 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, -1, -2], [4, -1, 5], [-1, 5, 4], [-3, 1, 2], [2, -4, 3], [-5, 2, -1], [-1, -5, 3], [-3, -4, 1], [-1, -3, -4], [-1, 5, -4], [5, 2, -1], [3, -1, -4], [-4, 2, 1], [-5, -3, 2], [-4, -1, -5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 201/1000 | Train Loss: 0.6260 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 202/1000 | Train Loss: 0.6261 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 203/1000 | Train Loss: 0.6266 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 204/1000 | Train Loss: 0.6268 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 205/1000 | Train Loss: 0.6271 | Val Loss: 0.6157
# Percentage of all-zero predictions: 100.00%
# Epoch 206/1000 | Train Loss: 0.6258 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 207/1000 | Train Loss: 0.6268 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 208/1000 | Train Loss: 0.6269 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 209/1000 | Train Loss: 0.6260 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 210/1000 | Train Loss: 0.6267 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-4, -1, -5], [5, -2, 3], [-3, 1, -2], [2, -1, -5], [5, -1, 2], [2, 5, 1], [-3, 1, 5], [-3, 4, 2], [4, -2, -1], [3, -4, -1], [5, -2, -3], [-4, -1, 5], [5, 2, -3], [5, 2, 3], [-2, 4, -1]]
# SAT solver solution: [0, 0, 1, 1, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 211/1000 | Train Loss: 0.6252 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 212/1000 | Train Loss: 0.6254 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 213/1000 | Train Loss: 0.6264 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 214/1000 | Train Loss: 0.6262 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 215/1000 | Train Loss: 0.6271 | Val Loss: 0.6156
# Percentage of all-zero predictions: 100.00%
# Epoch 216/1000 | Train Loss: 0.6271 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 217/1000 | Train Loss: 0.6271 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 218/1000 | Train Loss: 0.6266 | Val Loss: 0.6160
# Percentage of all-zero predictions: 100.00%
# Epoch 219/1000 | Train Loss: 0.6259 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 220/1000 | Train Loss: 0.6273 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[2, -5, -1], [-5, 2, 1], [-5, -4, 2], [-3, 1, -4], [3, 1, -2], [-5, -3, 4], [-2, 3, -4], [5, -4, 3], [5, -3, -1], [5, 4, 3], [-3, -1, 2], [-4, 1, 3], [-1, 2, -5], [4, -5, 1], [3, -4, 5]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 221/1000 | Train Loss: 0.6261 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
# Epoch 222/1000 | Train Loss: 0.6261 | Val Loss: 0.6132
# Percentage of all-zero predictions: 100.00%
# Epoch 223/1000 | Train Loss: 0.6253 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 224/1000 | Train Loss: 0.6260 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 225/1000 | Train Loss: 0.6267 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 226/1000 | Train Loss: 0.6251 | Val Loss: 0.6160
# Percentage of all-zero predictions: 100.00%
# Epoch 227/1000 | Train Loss: 0.6274 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 228/1000 | Train Loss: 0.6263 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 229/1000 | Train Loss: 0.6263 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 230/1000 | Train Loss: 0.6258 | Val Loss: 0.6134
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, -2, 4], [3, -2, 4], [4, -3, 1], [-1, 4, -3], [4, -5, 3], [-5, 1, -2], [-2, 5, -1], [3, -1, 4], [-4, -3, -2], [-5, -1, 3], [3, -1, 5], [-4, -3, 1], [5, 1, 4], [2, -1, 5], [-1, 4, 2]]
# SAT solver solution: [0, 0, 0, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 231/1000 | Train Loss: 0.6257 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 232/1000 | Train Loss: 0.6263 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
# Epoch 233/1000 | Train Loss: 0.6262 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 234/1000 | Train Loss: 0.6260 | Val Loss: 0.6157
# Percentage of all-zero predictions: 100.00%
# Epoch 235/1000 | Train Loss: 0.6270 | Val Loss: 0.6131
# Percentage of all-zero predictions: 100.00%
# Epoch 236/1000 | Train Loss: 0.6263 | Val Loss: 0.6172
# Percentage of all-zero predictions: 100.00%
# Epoch 237/1000 | Train Loss: 0.6275 | Val Loss: 0.6133
# Percentage of all-zero predictions: 100.00%
# Epoch 238/1000 | Train Loss: 0.6254 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
# Epoch 239/1000 | Train Loss: 0.6264 | Val Loss: 0.6132
# Percentage of all-zero predictions: 100.00%
# Epoch 240/1000 | Train Loss: 0.6263 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, -3, 1], [-5, -2, 3], [4, 1, 5], [-3, -4, -1], [4, 5, -1], [3, 2, 5], [-3, -1, -5], [1, -3, -4], [-1, -4, 5], [-1, -3, -2], [-5, -2, 3], [4, 5, -3], [3, -5, 1], [3, 5, -1], [-2, -4, 5]]
# SAT solver solution: [0, 0, 1, 0, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 241/1000 | Train Loss: 0.6257 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 242/1000 | Train Loss: 0.6267 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
# Epoch 243/1000 | Train Loss: 0.6257 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 244/1000 | Train Loss: 0.6258 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 245/1000 | Train Loss: 0.6266 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 246/1000 | Train Loss: 0.6249 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 247/1000 | Train Loss: 0.6269 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 248/1000 | Train Loss: 0.6253 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 249/1000 | Train Loss: 0.6253 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 250/1000 | Train Loss: 0.6261 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[1, -3, -4], [-4, 2, 5], [-5, 3, -2], [3, 4, 1], [3, -1, 2], [3, 5, 4], [-4, 2, 3], [-3, 2, -5], [-3, -4, 1], [-5, -4, 2], [5, 3, -2], [1, 3, -2], [-2, 1, -4], [-2, 4, 3], [1, -4, 3]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 251/1000 | Train Loss: 0.6276 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 252/1000 | Train Loss: 0.6260 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
# Epoch 253/1000 | Train Loss: 0.6255 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 254/1000 | Train Loss: 0.6266 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 255/1000 | Train Loss: 0.6256 | Val Loss: 0.6156
# Percentage of all-zero predictions: 100.00%
# Epoch 256/1000 | Train Loss: 0.6255 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 257/1000 | Train Loss: 0.6266 | Val Loss: 0.6134
# Percentage of all-zero predictions: 100.00%
# Epoch 258/1000 | Train Loss: 0.6255 | Val Loss: 0.6164
# Percentage of all-zero predictions: 100.00%
# Epoch 259/1000 | Train Loss: 0.6263 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 260/1000 | Train Loss: 0.6260 | Val Loss: 0.6134
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-2, 5, 4], [1, -5, 4], [-2, 4, 1], [-4, -5, 1], [-3, 5, -1], [-3, 4, 5], [-1, 5, -3], [-1, 4, -3], [1, -3, 4], [-5, -1, 3], [5, -4, -3], [3, 5, -4], [-3, 1, 4], [2, -3, -1], [2, 1, -3]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 261/1000 | Train Loss: 0.6265 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 262/1000 | Train Loss: 0.6261 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 263/1000 | Train Loss: 0.6247 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 264/1000 | Train Loss: 0.6260 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 265/1000 | Train Loss: 0.6258 | Val Loss: 0.6157
# Percentage of all-zero predictions: 100.00%
# Epoch 266/1000 | Train Loss: 0.6249 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 267/1000 | Train Loss: 0.6258 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 268/1000 | Train Loss: 0.6254 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 269/1000 | Train Loss: 0.6262 | Val Loss: 0.6131
# Percentage of all-zero predictions: 100.00%
# Epoch 270/1000 | Train Loss: 0.6253 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-4, -5, -1], [1, -5, 3], [5, -3, 1], [5, 4, 3], [2, 5, 3], [3, 1, 5], [-3, -1, 4], [3, 4, 1], [2, 1, -4], [3, -5, -4], [-5, 4, 1], [2, 4, 5], [5, 2, 4], [4, -5, -1], [1, 2, -5]]
# SAT solver solution: [1, 1, 1, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 271/1000 | Train Loss: 0.6258 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 272/1000 | Train Loss: 0.6257 | Val Loss: 0.6130
# Percentage of all-zero predictions: 100.00%
# Epoch 273/1000 | Train Loss: 0.6259 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 274/1000 | Train Loss: 0.6269 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 275/1000 | Train Loss: 0.6265 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 276/1000 | Train Loss: 0.6259 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 277/1000 | Train Loss: 0.6261 | Val Loss: 0.6155
# Percentage of all-zero predictions: 100.00%
# Epoch 278/1000 | Train Loss: 0.6264 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 279/1000 | Train Loss: 0.6262 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 280/1000 | Train Loss: 0.6260 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-2, -5, 3], [2, 4, -1], [-5, 4, 1], [-3, -4, -1], [5, 3, 1], [-1, -4, -3], [4, 2, -1], [1, -4, -2], [-2, 1, -3], [2, -3, -1], [5, -4, -3], [-4, 1, 5], [-4, 3, 2], [-3, 2, 4], [-3, -5, -1]]
# SAT solver solution: [1, 1, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 281/1000 | Train Loss: 0.6263 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 282/1000 | Train Loss: 0.6258 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 283/1000 | Train Loss: 0.6256 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 284/1000 | Train Loss: 0.6265 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 285/1000 | Train Loss: 0.6259 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 286/1000 | Train Loss: 0.6254 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 287/1000 | Train Loss: 0.6272 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 288/1000 | Train Loss: 0.6257 | Val Loss: 0.6152
# Percentage of all-zero predictions: 100.00%
# Epoch 289/1000 | Train Loss: 0.6273 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 290/1000 | Train Loss: 0.6254 | Val Loss: 0.6157
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, -3, 2], [4, -3, -2], [1, -2, -4], [-4, -5, -3], [5, -2, -1], [-1, -4, -3], [2, 4, -1], [3, -4, 2], [-5, 3, -2], [-1, -4, 2], [4, -2, -3], [3, 4, -1], [2, -3, 1], [-1, -5, 3], [-5, -3, 1]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 291/1000 | Train Loss: 0.6246 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 292/1000 | Train Loss: 0.6261 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 293/1000 | Train Loss: 0.6255 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 294/1000 | Train Loss: 0.6268 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 295/1000 | Train Loss: 0.6262 | Val Loss: 0.6160
# Percentage of all-zero predictions: 100.00%
# Epoch 296/1000 | Train Loss: 0.6255 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 297/1000 | Train Loss: 0.6255 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 298/1000 | Train Loss: 0.6247 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 299/1000 | Train Loss: 0.6251 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 300/1000 | Train Loss: 0.6254 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, -3, -2], [-5, 1, -4], [-4, -1, 2], [-1, 5, -2], [-5, -2, -4], [-2, -1, -5], [4, 2, 3], [-4, -1, -5], [1, 2, 3], [-5, -3, 2], [-2, -1, -5], [3, 5, 1], [4, 1, -5], [2, 3, -4], [3, -2, 5]]
# SAT solver solution: [1, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 301/1000 | Train Loss: 0.6260 | Val Loss: 0.6150
# Percentage of all-zero predictions: 100.00%
# Epoch 302/1000 | Train Loss: 0.6255 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 303/1000 | Train Loss: 0.6263 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 304/1000 | Train Loss: 0.6251 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 305/1000 | Train Loss: 0.6257 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 306/1000 | Train Loss: 0.6251 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 307/1000 | Train Loss: 0.6252 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 308/1000 | Train Loss: 0.6253 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 309/1000 | Train Loss: 0.6257 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 310/1000 | Train Loss: 0.6263 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[2, 3, -1], [-2, -1, 5], [-1, -2, -5], [-2, 3, 5], [3, -1, -5], [5, -2, -3], [3, -1, 4], [-1, -4, -5], [-1, 4, -5], [5, 4, 2], [4, -1, 3], [2, -4, -3], [-1, -3, 5], [2, 1, 3], [1, -4, 2]]
# SAT solver solution: [0, 1, 0, 1, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 311/1000 | Train Loss: 0.6253 | Val Loss: 0.6156
# Percentage of all-zero predictions: 100.00%
# Epoch 312/1000 | Train Loss: 0.6269 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 313/1000 | Train Loss: 0.6261 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 314/1000 | Train Loss: 0.6255 | Val Loss: 0.6159
# Percentage of all-zero predictions: 100.00%
# Epoch 315/1000 | Train Loss: 0.6267 | Val Loss: 0.6133
# Percentage of all-zero predictions: 100.00%
# Epoch 316/1000 | Train Loss: 0.6260 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 317/1000 | Train Loss: 0.6256 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 318/1000 | Train Loss: 0.6251 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 319/1000 | Train Loss: 0.6251 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 320/1000 | Train Loss: 0.6240 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-2, 5, 1], [-1, 4, 2], [4, -1, 3], [1, 3, 4], [2, -4, 5], [5, -1, 4], [-5, -3, 4], [5, 1, -2], [5, 3, 2], [5, -3, -4], [-5, -4, -2], [-3, 4, 1], [-2, -5, 4], [-4, -1, -3], [4, 1, 5]]
# SAT solver solution: [1, 1, 0, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 321/1000 | Train Loss: 0.6248 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 322/1000 | Train Loss: 0.6252 | Val Loss: 0.6137
# Percentage of all-zero predictions: 100.00%
# Epoch 323/1000 | Train Loss: 0.6248 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 324/1000 | Train Loss: 0.6275 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 325/1000 | Train Loss: 0.6265 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 326/1000 | Train Loss: 0.6257 | Val Loss: 0.6161
# Percentage of all-zero predictions: 100.00%
# Epoch 327/1000 | Train Loss: 0.6252 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 328/1000 | Train Loss: 0.6252 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 329/1000 | Train Loss: 0.6257 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 330/1000 | Train Loss: 0.6253 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, 3, 1], [-1, -4, -5], [-5, 4, 2], [-3, 2, -4], [-1, 5, 3], [-3, 1, 5], [-2, -4, -3], [5, 3, 4], [-4, 1, -2], [1, -5, 3], [1, -5, 2], [-1, -3, -2], [-4, 5, 2], [2, -1, 3], [2, -3, 5]]
# SAT solver solution: [1, 1, 0, 0, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 331/1000 | Train Loss: 0.6246 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 332/1000 | Train Loss: 0.6250 | Val Loss: 0.6135
# Percentage of all-zero predictions: 100.00%
# Epoch 333/1000 | Train Loss: 0.6252 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 334/1000 | Train Loss: 0.6247 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 335/1000 | Train Loss: 0.6251 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 336/1000 | Train Loss: 0.6266 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 337/1000 | Train Loss: 0.6261 | Val Loss: 0.6154
# Percentage of all-zero predictions: 100.00%
# Epoch 338/1000 | Train Loss: 0.6263 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 339/1000 | Train Loss: 0.6255 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 340/1000 | Train Loss: 0.6256 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[1, 3, -5], [-3, -1, -5], [2, -3, -5], [3, -5, -2], [2, -3, -5], [3, 5, 4], [4, 1, -2], [-4, -3, -5], [-1, 2, 5], [3, -4, -5], [-1, 5, -4], [-3, -2, -1], [-2, 4, -3], [-5, 1, 3], [4, 5, 1]]
# SAT solver solution: [0, 0, 1, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 341/1000 | Train Loss: 0.6267 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 342/1000 | Train Loss: 0.6259 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 343/1000 | Train Loss: 0.6251 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 344/1000 | Train Loss: 0.6250 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 345/1000 | Train Loss: 0.6250 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 346/1000 | Train Loss: 0.6255 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 347/1000 | Train Loss: 0.6260 | Val Loss: 0.6153
# Percentage of all-zero predictions: 100.00%
# Epoch 348/1000 | Train Loss: 0.6258 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 349/1000 | Train Loss: 0.6255 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 350/1000 | Train Loss: 0.6260 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[1, -2, 4], [5, -1, 3], [-5, -4, -1], [5, -1, -4], [-4, -3, 2], [-1, -3, 5], [3, 2, -4], [4, 1, -5], [2, 5, 1], [3, 1, -2], [-3, 1, -2], [1, -4, 3], [3, -1, 4], [-4, -2, -3], [1, -4, 5]]
# SAT solver solution: [1, 1, 1, 0, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 351/1000 | Train Loss: 0.6247 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 352/1000 | Train Loss: 0.6259 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 353/1000 | Train Loss: 0.6257 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 354/1000 | Train Loss: 0.6260 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 355/1000 | Train Loss: 0.6253 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 356/1000 | Train Loss: 0.6255 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 357/1000 | Train Loss: 0.6263 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 358/1000 | Train Loss: 0.6258 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 359/1000 | Train Loss: 0.6260 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 360/1000 | Train Loss: 0.6252 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-2, 3, 5], [-4, -2, -5], [5, -2, 4], [-3, -5, -2], [-2, -1, 5], [2, 3, 5], [5, -1, -4], [-4, -5, 3], [-2, 5, -1], [-2, 3, -4], [1, 5, 2], [-1, 2, -5], [1, 5, 3], [4, 3, 5], [4, 1, 3]]
# SAT solver solution: [1, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 361/1000 | Train Loss: 0.6265 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 362/1000 | Train Loss: 0.6259 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 363/1000 | Train Loss: 0.6267 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 364/1000 | Train Loss: 0.6256 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 365/1000 | Train Loss: 0.6254 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 366/1000 | Train Loss: 0.6255 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 367/1000 | Train Loss: 0.6262 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 368/1000 | Train Loss: 0.6254 | Val Loss: 0.6158
# Percentage of all-zero predictions: 100.00%
# Epoch 369/1000 | Train Loss: 0.6252 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 370/1000 | Train Loss: 0.6256 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[3, 4, -2], [4, 2, 5], [-5, 1, -4], [-4, -2, -5], [2, -5, -3], [1, 5, -4], [-2, -1, -5], [-3, 4, 5], [-3, 2, 5], [-1, 4, 5], [5, 3, 4], [-2, 1, -3], [4, 1, -2], [-5, 3, -1], [-3, 4, -2]]
# SAT solver solution: [1, 1, 0, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 371/1000 | Train Loss: 0.6251 | Val Loss: 0.6151
# Percentage of all-zero predictions: 100.00%
# Epoch 372/1000 | Train Loss: 0.6249 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 373/1000 | Train Loss: 0.6256 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 374/1000 | Train Loss: 0.6251 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# ...
# Percentage of all-zero predictions: 100.00%
# Epoch 880/1000 | Train Loss: 0.6260 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-3, 1, 4], [4, -5, -3], [3, -4, -1], [-2, 3, 1], [2, -3, 4], [-4, -1, 3], [-1, -3, 5], [-5, -2, -3], [-1, -5, -2], [-3, 4, -5], [3, -4, -1], [-1, -4, 2], [-4, -1, 3], [-2, -1, -3], [4, 3, -5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 881/1000 | Train Loss: 0.6250 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 882/1000 | Train Loss: 0.6256 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 883/1000 | Train Loss: 0.6244 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 884/1000 | Train Loss: 0.6253 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 885/1000 | Train Loss: 0.6250 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 886/1000 | Train Loss: 0.6248 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 887/1000 | Train Loss: 0.6252 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 888/1000 | Train Loss: 0.6245 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 889/1000 | Train Loss: 0.6259 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 890/1000 | Train Loss: 0.6254 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, 5, -1], [-5, -3, 4], [-4, -1, -5], [-1, -4, 3], [2, 4, 5], [-5, 4, -2], [4, 2, -1], [-5, -4, -3], [-2, -3, 1], [-2, -5, 1], [2, 1, 3], [-5, 3, -1], [3, -1, -4], [3, -1, -4], [-4, -5, 1]]
# SAT solver solution: [0, 1, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 891/1000 | Train Loss: 0.6256 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 892/1000 | Train Loss: 0.6258 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 893/1000 | Train Loss: 0.6252 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 894/1000 | Train Loss: 0.6257 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 895/1000 | Train Loss: 0.6252 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 896/1000 | Train Loss: 0.6253 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 897/1000 | Train Loss: 0.6246 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 898/1000 | Train Loss: 0.6252 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 899/1000 | Train Loss: 0.6254 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 900/1000 | Train Loss: 0.6265 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[3, 2, 5], [5, -1, -4], [-3, 1, -2], [-5, 4, 2], [-1, -3, 4], [1, 4, 5], [2, 3, -5], [-3, 1, -5], [-5, 2, -4], [4, 2, 3], [4, -2, -3], [2, 4, -1], [1, 2, 3], [-3, -2, 4], [2, -5, 4]]
# SAT solver solution: [1, 1, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 901/1000 | Train Loss: 0.6255 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 902/1000 | Train Loss: 0.6248 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 903/1000 | Train Loss: 0.6256 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 904/1000 | Train Loss: 0.6249 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 905/1000 | Train Loss: 0.6250 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 906/1000 | Train Loss: 0.6247 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 907/1000 | Train Loss: 0.6253 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 908/1000 | Train Loss: 0.6256 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 909/1000 | Train Loss: 0.6251 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 910/1000 | Train Loss: 0.6251 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-1, 5, -3], [-1, -5, 3], [4, 1, 2], [-1, -5, -4], [-1, 5, 3], [3, 4, 1], [3, 5, 1], [-1, -2, 3], [5, 2, -1], [2, -5, 1], [-1, -2, -5], [-4, -1, -5], [-4, 5, 2], [-1, -2, -3], [1, -2, 5]]
# SAT solver solution: [0, 1, 0, 1, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 911/1000 | Train Loss: 0.6255 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 912/1000 | Train Loss: 0.6247 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 913/1000 | Train Loss: 0.6250 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 914/1000 | Train Loss: 0.6259 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 915/1000 | Train Loss: 0.6259 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 916/1000 | Train Loss: 0.6255 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 917/1000 | Train Loss: 0.6255 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 918/1000 | Train Loss: 0.6256 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 919/1000 | Train Loss: 0.6256 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 920/1000 | Train Loss: 0.6248 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-1, 3, -2], [-3, -2, -1], [1, 4, 2], [4, -5, 2], [5, 3, -4], [-2, 3, 5], [-4, -1, 5], [-5, 4, -3], [4, -2, -5], [-1, 5, -2], [-4, 1, -5], [-4, -1, 2], [2, -1, -4], [-2, -3, -5], [-2, 1, -5]]
# SAT solver solution: [1, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 921/1000 | Train Loss: 0.6260 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 922/1000 | Train Loss: 0.6247 | Val Loss: 0.6147
# Percentage of all-zero predictions: 100.00%
# Epoch 923/1000 | Train Loss: 0.6254 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 924/1000 | Train Loss: 0.6255 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 925/1000 | Train Loss: 0.6245 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 926/1000 | Train Loss: 0.6252 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 927/1000 | Train Loss: 0.6260 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 928/1000 | Train Loss: 0.6243 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 929/1000 | Train Loss: 0.6250 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 930/1000 | Train Loss: 0.6252 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-4, -2, -3], [4, 3, -5], [4, 3, 2], [1, -4, -2], [-1, 3, 4], [5, 3, -2], [-4, 3, -5], [-1, 4, 5], [-2, -3, 1], [-1, 3, 2], [-3, 4, -2], [-4, 1, -5], [-2, -1, 4], [-5, 1, -3], [-4, 2, -1]]
# SAT solver solution: [0, 0, 1, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 931/1000 | Train Loss: 0.6252 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 932/1000 | Train Loss: 0.6262 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 933/1000 | Train Loss: 0.6258 | Val Loss: 0.6149
# Percentage of all-zero predictions: 100.00%
# Epoch 934/1000 | Train Loss: 0.6256 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 935/1000 | Train Loss: 0.6254 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 936/1000 | Train Loss: 0.6261 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 937/1000 | Train Loss: 0.6249 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 938/1000 | Train Loss: 0.6252 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 939/1000 | Train Loss: 0.6251 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 940/1000 | Train Loss: 0.6255 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[1, -4, -3], [-1, 5, -4], [2, -1, -3], [3, -5, 1], [-3, 2, -1], [2, -4, 1], [-1, 2, -3], [2, -1, 5], [5, 4, -3], [5, -2, -3], [1, 2, 3], [4, -3, 1], [-1, 2, 5], [-3, -1, 2], [-3, -5, -4]]
# SAT solver solution: [0, 1, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 941/1000 | Train Loss: 0.6254 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 942/1000 | Train Loss: 0.6250 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 943/1000 | Train Loss: 0.6248 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 944/1000 | Train Loss: 0.6247 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 945/1000 | Train Loss: 0.6256 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 946/1000 | Train Loss: 0.6252 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 947/1000 | Train Loss: 0.6250 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 948/1000 | Train Loss: 0.6253 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 949/1000 | Train Loss: 0.6260 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 950/1000 | Train Loss: 0.6244 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-5, 2, 3], [-1, 2, -3], [-2, -3, -5], [-3, 2, 4], [-1, 3, 2], [-2, 5, 1], [-2, -1, -4], [4, -3, 1], [-1, -2, -4], [-4, 1, 3], [-4, -1, 3], [1, -3, 5], [1, 4, -2], [-1, 3, 5], [-2, 1, -5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 951/1000 | Train Loss: 0.6256 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 952/1000 | Train Loss: 0.6252 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 953/1000 | Train Loss: 0.6253 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 954/1000 | Train Loss: 0.6259 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 955/1000 | Train Loss: 0.6248 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 956/1000 | Train Loss: 0.6248 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 957/1000 | Train Loss: 0.6248 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 958/1000 | Train Loss: 0.6251 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 959/1000 | Train Loss: 0.6253 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 960/1000 | Train Loss: 0.6255 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[1, 3, -4], [4, 2, -1], [2, 5, 1], [2, 4, 3], [-4, 5, 1], [-2, -3, -5], [5, -3, -4], [-2, -3, 4], [3, 2, 4], [3, -4, 5], [1, 2, 5], [-5, -4, 3], [-2, 3, 5], [-3, -4, 5], [3, 1, 5]]
# SAT solver solution: [1, 1, 0, 0, 1]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 961/1000 | Train Loss: 0.6253 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 962/1000 | Train Loss: 0.6252 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 963/1000 | Train Loss: 0.6260 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 964/1000 | Train Loss: 0.6254 | Val Loss: 0.6148
# Percentage of all-zero predictions: 100.00%
# Epoch 965/1000 | Train Loss: 0.6252 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 966/1000 | Train Loss: 0.6258 | Val Loss: 0.6138
# Percentage of all-zero predictions: 100.00%
# Epoch 967/1000 | Train Loss: 0.6251 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 968/1000 | Train Loss: 0.6253 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 969/1000 | Train Loss: 0.6254 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 970/1000 | Train Loss: 0.6245 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[4, 2, -3], [-5, -3, -2], [-1, -4, 5], [1, -3, -4], [-1, 4, -5], [3, -5, 1], [1, -4, 3], [-1, -2, -5], [2, -5, -4], [3, -4, 2], [4, -5, 1], [-3, 4, 1], [2, -1, -3], [3, -2, 4], [-3, -1, 2]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
#
# Epoch 971/1000 | Train Loss: 0.6245 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 972/1000 | Train Loss: 0.6264 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 973/1000 | Train Loss: 0.6244 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 974/1000 | Train Loss: 0.6248 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 975/1000 | Train Loss: 0.6253 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 976/1000 | Train Loss: 0.6253 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 977/1000 | Train Loss: 0.6253 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 978/1000 | Train Loss: 0.6246 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 979/1000 | Train Loss: 0.6263 | Val Loss: 0.6139
# Percentage of all-zero predictions: 100.00%
# Epoch 980/1000 | Train Loss: 0.6253 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[5, -3, 1], [-2, 1, 4], [2, 4, 3], [-2, 1, -5], [4, -3, -1], [1, -5, 3], [1, -3, 2], [-2, -1, -4], [-4, -5, -3], [-5, 2, 1], [4, 5, 3], [-4, -1, 2], [-2, 3, 1], [-1, -5, -4], [-4, -3, 1]]
# SAT solver solution: [0, 0, 0, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 981/1000 | Train Loss: 0.6258 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 982/1000 | Train Loss: 0.6254 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 983/1000 | Train Loss: 0.6245 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 984/1000 | Train Loss: 0.6255 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 985/1000 | Train Loss: 0.6249 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 986/1000 | Train Loss: 0.6259 | Val Loss: 0.6136
# Percentage of all-zero predictions: 100.00%
# Epoch 987/1000 | Train Loss: 0.6248 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 988/1000 | Train Loss: 0.6255 | Val Loss: 0.6143
# Percentage of all-zero predictions: 100.00%
# Epoch 989/1000 | Train Loss: 0.6252 | Val Loss: 0.6145
# Percentage of all-zero predictions: 100.00%
# Epoch 990/1000 | Train Loss: 0.6250 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[-3, -1, -5], [2, 1, -5], [-3, 2, 5], [-2, 3, -5], [5, 1, 2], [4, 5, 3], [1, -3, 4], [-4, -1, 2], [-3, 1, -4], [-3, 4, 2], [-3, -1, -4], [-5, 4, 2], [2, 5, -4], [-4, -5, -3], [5, -3, -1]]
# SAT solver solution: [1, 1, 0, 1, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: False
#
# Epoch 991/1000 | Train Loss: 0.6263 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 992/1000 | Train Loss: 0.6260 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 993/1000 | Train Loss: 0.6248 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 994/1000 | Train Loss: 0.6254 | Val Loss: 0.6144
# Percentage of all-zero predictions: 100.00%
# Epoch 995/1000 | Train Loss: 0.6243 | Val Loss: 0.6146
# Percentage of all-zero predictions: 100.00%
# Epoch 996/1000 | Train Loss: 0.6256 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 997/1000 | Train Loss: 0.6247 | Val Loss: 0.6141
# Percentage of all-zero predictions: 100.00%
# Epoch 998/1000 | Train Loss: 0.6258 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
# Epoch 999/1000 | Train Loss: 0.6248 | Val Loss: 0.6142
# Percentage of all-zero predictions: 100.00%
# Epoch 1000/1000 | Train Loss: 0.6251 | Val Loss: 0.6140
# Percentage of all-zero predictions: 100.00%
#
# Sample test case:
# Clauses: [[3, -2, 1], [-3, -5, -4], [1, 2, -4], [-1, -5, 3], [-5, -3, 2], [1, -5, -3], [5, -2, 3], [-1, 2, -3], [5, -1, 2], [5, -1, -4], [-5, -1, -3], [-3, 4, -5], [4, -5, -3], [4, -5, 3], [-1, -3, 5]]
# SAT solver solution: [0, 0, 0, 0, 0]
# Model prediction: [0, 0, 0, 0, 0]
# Match: True
